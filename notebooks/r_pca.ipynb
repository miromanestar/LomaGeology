23: got 'PLEISTOCENE [49]'"
# Warning message:
# "Expecting logical in W7001 / R7001C23: got 'PLEISTOCENE [49]'"
# Warning message:
# "Expecting logical in W7002 / R7002C23: got 'HOLOCENE [49]'"
# Warning message:
# "Expecting logical in W7003 / R7003C23: got 'PLEISTOCENE [49]'"
# Warning message:
# "Expecting logical in W7122 / R7122C23: got 'PLEISTOCENE [1995]'"
# Warning message:
# "Expecting numeric in U7538 / R7538C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7543 / R7543C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7544 / R7544C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7545 / R7545C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7546 / R7546C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7547 / R7547C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7548 / R7548C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7549 / R7549C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7550 / R7550C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7551 / R7551C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7552 / R7552C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7553 / R7553C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7558 / R7558C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7560 / R7560C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7561 / R7561C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7562 / R7562C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7563 / R7563C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7564 / R7564C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7565 / R7565C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7566 / R7566C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7567 / R7567C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7568 / R7568C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7569 / R7569C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7570 / R7570C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7571 / R7571C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7572 / R7572C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7573 / R7573C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7574 / R7574C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7575 / R7575C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7576 / R7576C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7577 / R7577C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7578 / R7578C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7579 / R7579C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7580 / R7580C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7581 / R7581C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7582 / R7582C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7583 / R7583C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7584 / R7584C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7585 / R7585C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7586 / R7586C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7588 / R7588C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7589 / R7589C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7590 / R7590C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7591 / R7591C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7844 / R7844C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7845 / R7845C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7846 / R7846C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7847 / R7847C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7848 / R7848C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7849 / R7849C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7850 / R7850C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7851 / R7851C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7852 / R7852C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7853 / R7853C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7854 / R7854C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U7855 / R7855C21: got '47000 [9393]'"
# Warning message:
# "Expecting logical in W7884 / R7884C23: got 'PREHISTORIC [1431]'"
# Warning message:
# "Expecting numeric in U8118 / R8118C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U8119 / R8119C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U8120 / R8120C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U8121 / R8121C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U8122 / R8122C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U8123 / R8123C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U8124 / R8124C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U8125 / R8125C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U8126 / R8126C21: got '47000 [9393]'"
# Warning message:
# "Expecting numeric in U8127 / R8127C21: got '47000 [9393]'"
# Warning message:
# "Expecting logical in W8128 / R8128C23: got 'PREHISTORIC [10565]'"
# Warning message:
# "Expecting logical in W8129 / R8129C23: got 'PREHISTORIC [10565]'"
# Warning message:
# "Expecting logical in W8130 / R8130C23: got 'PREHISTORIC [10565]'"
# Warning message:
# "Expecting logical in W8131 / R8131C23: got 'PREHISTORIC [10565]'"
# Warning message:
# "Expecting logical in W8132 / R8132C23: got 'PREHISTORIC [10565]'"
# Warning message:
# "Expecting logical in W8133 / R8133C23: got 'PREHISTORIC [10565]'"
# Warning message:
# "Expecting logical in W8134 / R8134C23: got 'PREHISTORIC [10565]'"
# Warning message:
# "Expecting logical in W8135 / R8135C23: got 'PREHISTORIC [10565]'"
# Warning message:
# "Expecting logical in W8136 / R8136C23: got 'PREHISTORIC [10565]'"
# Warning message:
# "Expecting logical in W8137 / R8137C23: got 'PREHISTORIC [10565]'"
# Warning message:
# "Expecting logical in W8138 / R8138C23: got 'PREHISTORIC [10565]'"
# Warning message:
# "Expecting logical in W8161 / R8161C23: got 'PREHISTORIC [10565]'"
# Warning message:
# "Expecting logical in W8666 / R8666C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8667 / R8667C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8668 / R8668C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8669 / R8669C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8670 / R8670C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8671 / R8671C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8672 / R8672C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8673 / R8673C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting numeric in U8684 / R8684C21: got '400000 [7190]'"
# Warning message:
# "Expecting numeric in U8685 / R8685C21: got '400000 [7190]'"
# Warning message:
# "Expecting numeric in U8686 / R8686C21: got '400000 [7190]'"
# Warning message:
# "Expecting numeric in U8687 / R8687C21: got '400000 [7190]'"
# Warning message:
# "Expecting numeric in U8688 / R8688C21: got '400000 [7190]'"
# Warning message:
# "Expecting logical in W8851 / R8851C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8852 / R8852C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8853 / R8853C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8854 / R8854C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8855 / R8855C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8856 / R8856C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8857 / R8857C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8858 / R8858C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8859 / R8859C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8860 / R8860C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8861 / R8861C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8862 / R8862C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8863 / R8863C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8864 / R8864C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8865 / R8865C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8866 / R8866C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8867 / R8867C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W8868 / R8868C23: got 'NEOGENE [14499]'"
# Warning message:
# "Expecting logical in W
23: got 'PLIOCENE [19624]'"
# Warning message:
# "Expecting logical in W9368 / R9368C23: got 'PLIOCENE [19624]'"
# Warning message:
# "Expecting logical in W9769 / R9769C23: got 'PLEISTOCENE [136]'"
# Warning message:
# "Expecting logical in W9790 / R9790C23: got 'PLEISTOCENE [324]'"
# Warning message:
# "Expecting logical in W9953 / R9953C23: got 'PLEISTOCENE [10015]'"
# Warning message:
# "Expecting logical in W9954 / R9954C23: got 'PLEISTOCENE [10015]'"
# Warning message:
# "Expecting logical in W9957 / R9957C23: got 'PLEISTOCENE [10015]'"
# Warning message:
# "Expecting logical in W9962 / R9962C23: got 'PLEISTOCENE [10015]'"
# Warning message:
# "Expecting logical in W9963 / R9963C23: got 'PLEISTOCENE [10015]'"
# Warning message:
# "Expecting logical in W9964 / R9964C23: got 'PLEISTOCENE [10015]'"
# Warning message:
# "Expecting logical in W9966 / R9966C23: got 'PLEISTOCENE [10015]'"
# Warning message:
# "Expecting logical in W9969 / R9969C23: got 'PLEISTOCENE [10015]'"
# Warning message:
# "Expecting logical in W9970 / R9970C23: got 'PLEISTOCENE [10015]'"
# Warning message:
# "Expecting logical in W9971 / R9971C23: got 'PLEISTOCENE [10015]'"
# Warning message:
# "Expecting logical in W9973 / R9973C23: got 'PLEISTOCENE [10015]'"
# Warning message:
# "Expecting logical in W9974 / R9974C23: got 'PLEISTOCENE [10015]'"
# Warning message:
# "Expecting logical in W9977 / R9977C23: got 'PLEISTOCENE [10015]'"
# Warning message:
# "Expecting logical in W9979 / R9979C23: got 'PLEISTOCENE [10015]'"
# Warning message:
# "Expecting logical in W9980 / R9980C23: got 'PLEISTOCENE [10015]'"
# Warning message:
# "Expecting logical in W9981 / R9981C23: got 'PLEISTOCENE [10015]'"
# Warning message:
# "Expecting logical in W9983 / R9983C23: got 'PLEISTOCENE [10015]'"
# Warning message:
# "Expecting logical in W9984 / R9984C23: got 'PLEISTOCENE [10015]'"
# Warning message:
# "Expecting logical in W9985 / R9985C23: got 'PLEISTOCENE [10015]'"
# Warning message:
# "Expecting logical in W10281 / R10281C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10282 / R10282C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10283 / R10283C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10284 / R10284C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10285 / R10285C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10286 / R10286C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10287 / R10287C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10288 / R10288C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10289 / R10289C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10290 / R10290C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10291 / R10291C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10292 / R10292C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10293 / R10293C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10294 / R10294C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10295 / R10295C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10296 / R10296C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10297 / R10297C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10298 / R10298C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10299 / R10299C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10300 / R10300C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10301 / R10301C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10302 / R10302C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10303 / R10303C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10304 / R10304C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10305 / R10305C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10306 / R10306C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10307 / R10307C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10308 / R10308C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10309 / R10309C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10310 / R10310C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10311 / R10311C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10399 / R10399C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10400 / R10400C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10401 / R10401C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10402 / R10402C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10403 / R10403C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10404 / R10404C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10405 / R10405C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10406 / R10406C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10407 / R10407C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10408 / R10408C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10409 / R10409C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10410 / R10410C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10411 / R10411C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10412 / R10412C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10413 / R10413C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10414 / R10414C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10415 / R10415C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10416 / R10416C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10417 / R10417C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10418 / R10418C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10419 / R10419C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10420 / R10420C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10421 / R10421C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10422 / R10422C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10423 / R10423C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10424 / R10424C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10425 / R10425C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10426 / R10426C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10427 / R10427C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10428 / R10428C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10429 / R10429C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10430 / R10430C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10431 / R10431C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10432 / R10432C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10436 / R10436C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10437 / R10437C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting numeric in U10438 / R10438C21: got '1000000 [7190]'"
# Warning message:
# "Expecting numeric in U10439 / R10439C21: got '1000000 [7190]'"
# Warning message:
# "Expecting numeric in U10440 / R10440C21: got '1000000 [7190]'"
# Warning message:
# "Expecting logical in W10441 / R10441C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10442 / R10442C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10443 / R10443C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10444 / R10444C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10445 / R10445C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10446 / R10446C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10447 / R10447C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10448 / R10448C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting logical in W10449 / R10449C23: got 'PLEISTOCENE [21071]'"
# Warning message:
# "Expecting numeric in U10624 / R10624C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10628 / R10628C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10629 / R10629C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10631 / R10631C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10632 / R10632C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10633 / R10633C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10635 / R10635C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10637 / R10637C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10638 / R10638C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10640 / R10640C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10667 / R10667C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10668 / R10668C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10669 / R10669C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10670 / R10670C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10726 / R10726C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10727 / R10727C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10728 / R10728C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10729 / R10729C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10731 / R10731C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10732 / R10732C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10733 / R10733C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10734 / R10734C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10735 / R10735C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10736 / R10736C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10737 / R10737C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10738 / R10738C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10740 / R10740C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10741 / R10741C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10742 / R10742C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10743 / R10743C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10744 / R10744C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U10745 / R10745C21: got '1000000 [12504]'"
# Warning message:
# "Expecting numeric in U
23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12639 / R12639C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12640 / R12640C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12641 / R12641C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12642 / R12642C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12643 / R12643C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12644 / R12644C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12645 / R12645C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12646 / R12646C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12647 / R12647C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12648 / R12648C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12649 / R12649C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12650 / R12650C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12651 / R12651C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12652 / R12652C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12653 / R12653C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12654 / R12654C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12655 / R12655C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12656 / R12656C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12657 / R12657C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12658 / R12658C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12659 / R12659C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12660 / R12660C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12661 / R12661C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12662 / R12662C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12663 / R12663C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12664 / R12664C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12665 / R12665C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12666 / R12666C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12667 / R12667C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12668 / R12668C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12669 / R12669C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12670 / R12670C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12671 / R12671C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12672 / R12672C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12673 / R12673C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12674 / R12674C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12675 / R12675C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12676 / R12676C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12677 / R12677C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12678 / R12678C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12679 / R12679C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12680 / R12680C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12681 / R12681C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting logical in W12682 / R12682C23: got 'PLIOCENE [14135]'"
# Warning message:
# "Expecting numeric in AL12968 / R12968C38: got '<0.002'"
# Warning message:
# "Expecting numeric in CU12968 / R12968C99: got '<10'"
# Warning message:
# "Expecting numeric in CX12968 / R12968C102: got '<1'"
# Warning message:
# "Expecting logical in DD12968 / R12968C108: got '<5'"
# Warning message:
# "Expecting logical in DP12968 / R12968C120: got '<0.5'"
# Warning message:
# "Expecting logical in DQ12968 / R12968C121: got '<0.5'"
# Warning message:
# "Expecting numeric in EV12968 / R12968C152: got '<10'"
# Warning message:
# "Expecting logical in GC12968 / R12968C185: got '<0.01'"
# Warning message:
# "Expecting logical in DD12969 / R12969C108: got '<5'"
# Warning message:
# "Expecting logical in DP12969 / R12969C120: got '<0.5'"
# Warning message:
# "Expecting numeric in EV12969 / R12969C152: got '<10'"
# Warning message:
# "Expecting logical in DD12970 / R12970C108: got '<5'"
# Warning message:
# "Expecting logical in DP12970 / R12970C120: got '<0.5'"
# Warning message:
# "Expecting numeric in EV12970 / R12970C152: got '<10'"
# Warning message:
# "Expecting logical in DD12971 / R12971C108: got '<5'"
# Warning message:
# "Expecting logical in DP12971 / R12971C120: got '<0.5'"
# Warning message:
# "Expecting numeric in EV12971 / R12971C152: got '<10'"
# Warning message:
# "Expecting logical in DD12972 / R12972C108: got '<5'"
# Warning message:
# "Expecting logical in DP12972 / R12972C120: got '<0.5'"
# Warning message:
# "Expecting numeric in EV12972 / R12972C152: got '<10'"
# Warning message:
# "Expecting numeric in EW12972 / R12972C153: got '<2'"
# Warning message:
# "Expecting numeric in AL12973 / R12973C38: got '<0.002'"
# Warning message:
# "Expecting numeric in CU12973 / R12973C99: got '<10'"
# Warning message:
# "Expecting logical in DP12973 / R12973C120: got '<0.5'"
# Warning message:
# "Expecting logical in DQ12973 / R12973C121: got '<0.5'"
# Warning message:
# "Expecting numeric in EV12973 / R12973C152: got '<10'"
# Warning message:
# "Expecting logical in DD12974 / R12974C108: got '<5'"
# Warning message:
# "Expecting numeric in DL12974 / R12974C116: got '<1'"
# Warning message:
# "Expecting logical in DP12974 / R12974C120: got '<0.5'"
# Warning message:
# "Expecting numeric in EV12974 / R12974C152: got '<10'"
# Warning message:
# "Expecting numeric in EW12974 / R12974C153: got '<2'"
# Warning message:
# "Expecting logical in DP12975 / R12975C120: got '<0.5'"
# Warning message:
# "Expecting numeric in EO12975 / R12975C145: got '<1'"
# Warning message:
# "Expecting numeric in EV12975 / R12975C152: got '<10'"
# Warning message:
# "Expecting logical in DD12976 / R12976C108: got '<5'"
# Warning message:
# "Expecting logical in DP12976 / R12976C120: got '<0.5'"
# Warning message:
# "Expecting numeric in EV12976 / R12976C152: got '<10'"
# Warning message:
# "Expecting numeric in EW12976 / R12976C153: got '<2'"
# Warning message:
# "Expecting logical in DP12977 / R12977C120: got '<0.5'"
# Warning message:
# "Expecting numeric in EV12977 / R12977C152: got '<10'"
# Warning message:
# "Expecting logical in DD12978 / R12978C108: got '<5'"
# Warning message:
# "Expecting numeric in DL12978 / R12978C116: got '<1'"
# Warning message:
# "Expecting logical in DP12978 / R12978C120: got '<0.5'"
# Warning message:
# "Expecting numeric in EO12978 / R12978C145: got '<1'"
# Warning message:
# "Expecting numeric in EV12978 / R12978C152: got '<10'"
# Warning message:
# "Expecting numeric in EW12978 / R12978C153: got '<2'"
# Warning message:
# "Expecting logical in DP12979 / R12979C120: got '<0.5'"
# Warning message:
# "Expecting numeric in EV12979 / R12979C152: got '<10'"
# Warning message:
# "Expecting logical in DD12980 / R12980C108: got '<5'"
# Warning message:
# "Expecting logical in DP12980 / R12980C120: got '<0.5'"
# Warning message:
# "Expecting numeric in EV12980 / R12980C152: got '<10'"
# Warning message:
# "Expecting logical in DD12981 / R12981C108: got '<5'"
# Warning message:
# "Expecting numeric in DL12981 / R12981C116: got '<1'"
# Warning message:
# "Expecting logical in DP12981 / R12981C120: got '<0.5'"
# Warning message:
# "Expecting numeric in EO12981 / R12981C145: got '<1'"
# Warning message:
# "Expecting numeric in EV12981 / R12981C152: got '<10'"
# Warning message:
# "Expecting numeric in CD12982 / R12982C82: got '<10'"
# Warning message:
# "Expecting logical in DD12982 / R12982C108: got '<5'"
# Warning message:
# "Expecting logical in DP12982 / R12982C120: got '<0.5'"
# Warning message:
# "Expecting numeric in EV12982 / R12982C152: got '<10'"
# Warning message:
# "Expecting numeric in EW12982 / R12982C153: got '<2'"
# Warning message:
# "Expecting numeric in CD12983 / R12983C82: got '<10'"
# Warning message:
# "Expecting logical in DD12983 / R12983C108: got '<5'"
# Warning message:
# "Expecting numeric in DL12983 / R12983C116: got '<1'"
# Warning message:
# "Expecting logical in DP12983 / R12983C120: got '<0.5'"
# Warning message:
# "Expecting numeric in EO12983 / R12983C145: got '<1'"
# Warning message:
# "Expecting numeric in EV12983 / R12983C152: got '<10'"
# Warning message:
# "Expecting numeric in EW12983 / R12983C153: got '<2'"
# Warning message:
# "Expecting logical in DP12984 / R12984C120: got '<0.5'"
# Warning message:
# "Expecting numeric in EO12984 / R12984C145: got '<1'"
# Warning message:
# "Expecting numeric in EV12984 / R12984C152: got '<10'"
# Warning message:
# "Expecting logical in DD12985 / R12985C108: got '<5'"
# Warning message:
# "Expecting numeric in DL12985 / R12985C116: got '<1'"
# Warning message:
# "Expecting logical in DP12985 / R12985C120: got '<0.5'"
# Warning message:
# "Expecting numeric in EV12985 / R12985C152: got '<10'"
# Warning message:
# "Expecting numeric in EW12985 / R12985C153: got '<2'"
# New names:
# • `` -> `...184`
# • `` -> `...191`
# • `Sr/Nb` -> `Sr/Nb...193`
# • `Sr/Nb` -> `Sr/Nb...195`

# %%
library(tidyverse)

numerical_data <- hawaii %>% select_if(is.numeric) # Filter out non-numerical fields
primaries <- select(numerical_data,
    "ISLAND",
    "VOLCANO",
    # Major Elements
    "SIO2(WT%)",
    "TIO2(WT%)", 
    "AL2O3(WT%)", 
    "FeO (Calc)", 
    "CAO(WT%)", 
    "MGO(WT%)", 
    "K2O(WT%)", 
    "NA2O(WT%)",
    # Minor Elements
    # "P2O5(WT%)",
    # "MNO(WT%)", 
)

# Filter out data with missing values
data <- primaries[complete.cases(primaries), ]
sprintf('Number of samples: %s', nrow(data))
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6      ✔ purrr   0.3.4
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# [1] "Number of samples: 10476"

# %%
library(factoextra)
library(corrplot)

# c(-1, -2) filters out first two columns (ISLAND, VOLCANO)
pca <- prcomp(data[, c(-1, -2)], scale = TRUE)
var <- get_pca_var(pca)
ind <- get_pca_ind(pca)

fviz_eig(pca, addlabels = TRUE)
corrplot(var$cos2, is.corr=FALSE)
# Out:
# Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa
#
# corrplot 0.92 loaded
# plot without title
# Plot with title ""

# %%
dim <- 3

set.seed(123)
km_var <- kmeans(var$coord, centers = dim, nstart = 25)
km_ind <- kmeans(ind$coord, centers = dim, nstart = 25)
km_var.grp <- as.factor(km_var$cluster)
km_ind.grp <- as.factor(km_ind$cluster)

# rmse_var <- sqrt(sum(km_var$withinss) / nrow(var$coord))
rmse_ind <- sqrt(sum(km_ind$withinss) / nrow(ind$coord))

sprintf('RMSE: %s', rmse_ind)

for (i in 1:dim) {

  print(fviz_contrib(pca, choice = "var", axes = i, top = 10))

  for (k in 1:dim) {
    if (k == i) {
      next
    }
    print(fviz_pca_var(
      pca, 
      col.var = 'cos2', 
      gradient.cols = c('#00AFBB', '#E7B800', '#FC4E07'), 
      repel = TRUE,
      axes = c(i, k)
    ))

    print(fviz_pca(pca, 
      col.ind = km_ind.grp,
      col.var = 'black',
      geom.ind = "point", 
      addEllipses = TRUE, 
      legend.title = "Cluster",
      axes = c(i, k)
    ))

    # print(fviz_pca_ind(
    #     pca,
    #     geom.ind = 'point',
    #     col.ind = factor(data$ISLAND),
    #     addEllipses = TRUE,
    #     legend.title = 'Clusters',
    #     axes = c(i, k)
    # ))
  }
}
# Out:
# [1] "RMSE: 2.11515210961959"
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
set.seed(123)
ind <- get_pca_ind(pca)
km_var <- kmeans(var$coord, centers = dim, nstart = 25)
km_ind <- kmeans(ind$coord, centers = dim, nstart = 25)
km_var.grp <- as.factor(km_var$cluster)
km_ind.grp <- as.factor(km_ind$cluster)

fviz_pca(pca, 
    col.ind = km_ind.grp,
    col.var = km_var.grp,
    geom.ind = "point", 
    addEllipses = TRUE, 
    legend.title = "Cluster",
)

fviz_pca_ind(
    pca,
    geom.ind = 'point',
    col.ind = factor(data$VOLCANO),
    addEllipses = TRUE,
    legend.title = 'Clusters'
)

# Display KMeans
fviz_cluster(
    km_ind, 
    data = ind$coord,
    palette = c("#2E9FDF", "#00AFBB", "#E7B800"), 
    geom = "point",
    ellipse.type = "convex", 
    ggtheme = theme_bw(),
    axes = c(2, 3)
    )

# fviz_pca_var(
#     pca,
#     col.var = grp,
#     palette = c("#0073C2FF", "#EFC000FF", "#868686FF", "#9AD4D6", "#F2B8B8"),
#     legend.title = 'Cluster'
# )
# fviz_pca(
#     pca,
#     geom.ind = 'point',
#     col.var = grp,
#     col.ind = 'black',
#     palette = c("#0073C2FF", "#EFC000FF", "#868686FF", "#9AD4D6", "#F2B8B8"),
# )
# fviz_cluster(
#     km,
#     data = ind$coord,
#     geom = "point",
#     ellipse.type = "euclid",
# )
# Out:
# plot without title
# plot without title
# plot without title
